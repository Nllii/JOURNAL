# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import siaskynet as skynet

# %%
joblistings = pd.read_csv("master_list.csv")
joblistings = joblistings.drop(['blurb', 'id','status','tags','query','date','provider','location'], axis=1)
joblistings.head(22)
# Out:
#                                                 title  \
# 0       Palliative RN Care Manager WellMed Houston TX
# 1                      Facility Phlebotomist- Floater
# 2                    Facility Phlebotomist- Champions
# 3                     Phlebotomist - Laboratory (PRN)
# 4                     Phlebotomist - Laboratory (PRN)
# 5                      Infusion Registered Nurse (RN)
# 6                    Registered Nurse (RN) PRN CV IMU
# 7           Certified or Registered Medical Assistant
# 8   Full-time Sitter For 80-year Old Mother Recove...
# 9        Registered Nurse (RN) (PRN) Neuro Trauma ICU
# 10                                       Phlebotomist
# 11                                       Phlebotomist
# 12                             Research Coordinator I
# 13                                    Phlebotomist II
# 14          MLT/MT- Medical Technologist-Deke Slayton
# 15                               RN Home Health Nurse
# ...

# %%
f= open("joblinks.csv","w+")
f.write(str(joblistings))
f.close()
joblistings["link"]
# Out:
# 0     https://job-openings.monster.com/palliative-rn...
# 1     http://www.indeed.com/viewjob?jk=9de4736cd3798a59
# 2     http://www.indeed.com/viewjob?jk=af1b668f256bc7ac
# 3     http://www.indeed.com/viewjob?jk=9042e380a7a08284
# 4     http://www.indeed.com/viewjob?jk=dacbe91889650bc3
# 5     https://job-openings.monster.com/infusion-regi...
# 6     https://job-openings.monster.com/registered-nu...
# 7     https://job-openings.monster.com/certified-or-...
# 8     https://job-openings.monster.com/full-time-sit...
# 9     https://job-openings.monster.com/registered-nu...
# 10    http://www.indeed.com/viewjob?jk=c635abc7be2598e2
# 11    http://www.indeed.com/viewjob?jk=f6781693e6687700
# 12    http://www.indeed.com/viewjob?jk=4fcb12382c8cc331
# 13    http://www.indeed.com/viewjob?jk=14091fada24d19f7
# 14    https://job-openings.monster.com/mlt-mt-medica...
# 15    https://job-openings.monster.com/rn-home-healt...
# 16    https://job-openings.monster.com/phlebotomist-...
# ...
